# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = np.fromfile('hello.raw16', '<i2')

# %%
len(data) == 4032*3032
# Out:
# True

# %%
img = np.reshape(data, (3032, 4032))
plt.figure(figsize = (200,20))
plt.imshow(img, cmap='gray', origin='lower')
